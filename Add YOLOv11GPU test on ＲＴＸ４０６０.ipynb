# %% [markdown]
# bus.jpg: 640x480 4 persons, 1 bus, 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 480)
# {'preprocess': 1.636899999994057, 'inference': 42.38640000005489, 'postprocess': 7.097299999941242}

# %%
from ultralytics import YOLO

# 加载 nano 
model = YOLO("yolo11n.pt")

# 测试单张图片
results = model("https://ultralytics.com/images/bus.jpg")
results[0].show()

# 显示检测结果的速度
print(results[0].speed)  # print inference time, should be <10ms
